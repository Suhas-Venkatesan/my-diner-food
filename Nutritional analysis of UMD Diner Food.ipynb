# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_csv("the-diner-dinner.csv" ,engine="python", error_bad_lines=False, index_col=0)
# Out:
# Skipping line 325: Expected 24 fields in line 325, saw 25
# Skipping line 2126: Expected 24 fields in line 2126, saw 26

# %%
data
# Out:
#                                         Calories  Serving size  \
# Food name
# Chicken Philly Meat                          125            4
# Tomato Mushroom Spinach Philly Filling        30            4
# Banana Peppers                                 5            1
# Blue Cheese Crumbles                         100            1
# Carrot White Bean Veggie Fries               131            3
# ...                                          ...           ...
# Cream Cheese Onion and Chive                  93            1
# Donuts                                       684            1
# Maple Syrup                                   58            1
# Margarine                                    203            1
# Plain Cream Cheese                           101            1
#
#                                         Serving size with units(each/oz)  \
# Food name
# Chicken Philly Meat                                                 4 oz
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data[" Sodium(mg)"]
# Out:
# Food name
# Chicken Philly Meat                          74
# Tomato Mushroom Spinach Philly Filling     33.1
# Banana Peppers                              378
# Blue Cheese Crumbles                      395.5
# Carrot White Bean Veggie Fries            191.3
#                                           ...
# Cream Cheese Onion and Chive               85.8
# Donuts                                    222.3
# Maple Syrup                                66.4
# Margarine                                 212.6
# Plain Cream Cheese                         96.2
# Name:  Sodium(mg), Length: 6194, dtype: object
